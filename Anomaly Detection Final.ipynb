# %% [markdown]
# # Credit Card Fraud Detection
# This notebook will guide you through the process of building a machine learning model to detect fraudulent transactions. We will be using the 2013 European credit card fraud dataset from Kaggle. The steps we will follow are:
#
# 1. **Exploratory Data Analysis (EDA)**: We will start by loading the dataset and performing an initial analysis to understand the data. This will include checking the data types, missing values, summary statistics, and visualizing the distributions of variables.
#
# 2. **Data Preprocessing**: The dataset is highly imbalanced, so we will apply techniques to balance it. This could include oversampling the minority class (fraudulent transactions), undersampling the majority class (non-fraudulent transactions), or using a combination of both.
#
# 3. **Feature Selection**: We will identify the most relevant or correlated variables with the 'Class' variable, which indicates whether a transaction is fraudulent or not. This can be done using correlation analysis, chi-square test, or any other suitable feature selection method.
#
# 4. **Model Training**: We will train four different models - Local Outlier Factor, K-means clustering, Support Vector Machines (SVM), and XGBoost - using the selected features. We will use cross-validation to ensure the robustness of the models.
#
# 5. **Hyperparameter Optimization**: We will optimize the hyperparameters used to improve our scores and lower our models' mistakes with its predictions.
#
# 6. **Model Evaluation**: We will evaluate the performance of each model using precision, F1-score, AUC-ROC, and recall metrics. Also, we will create confusion matrices to evaluate the models based on True Positives (TP), True Negatives (TN), False Positives (FP), and False Negatives (FN).
#
# 7. **Model Comparison**: We will compare the performance of the four models and select the best performing one. If other models compensate for the insufficiencies of others, we will suggest a hybrid model.
#
# Each step will be well-documented with markdown cells explaining the process and findings. We will also include necessary visualizations for better understanding.

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '.'

# %%
# !chmod 600 kaggle.json

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# In this section, we will start by loading the dataset and performing an initial analysis to understand the data. This will include checking the data types, missing values, summary statistics, and visualizing the distributions of variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('creditcard.csv')

# Display the first few rows of the dataframe
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time</th>
#       <th>V1</th>
#       <th>V2</th>
#       <th>V3</th>
#       <th>V4</th>
#       <th>V5</th>
#       <th>V6</th>
#       <th>V7</th>
#       <th>V8</th>
#       <th>V9</th>
#       <th>...</th>
#       <th>V21</th>
#       <th>V22</th>
#       <th>V23</th>
#       <th>V24</th>
#       <th>V25</th>
#       <th>V26</th>
#       <th>V27</th>
#       <th>V28</th>
#       <th>Amount</th>
#       <th>Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.0</td>
#       <td>-1.359807</td>
#       <td>-0.072781</td>
#       <td>2.536347</td>
#       <td>1.378155</td>
# ...

# %%
# Check data types
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Generate summary statistics
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time</th>
#       <th>V1</th>
#       <th>V2</th>
#       <th>V3</th>
#       <th>V4</th>
#       <th>V5</th>
#       <th>V6</th>
#       <th>V7</th>
#       <th>V8</th>
#       <th>V9</th>
#       <th>...</th>
#       <th>V21</th>
#       <th>V22</th>
#       <th>V23</th>
#       <th>V24</th>
#       <th>V25</th>
#       <th>V26</th>
#       <th>V27</th>
#       <th>V28</th>
#       <th>Amount</th>
#       <th>Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>284807.000000</td>
#       <td>2.848070e+05</td>
#       <td>2.848070e+05</td>
#       <td>2.848070e+05</td>
# ...

# %%
import matplotlib.pyplot as plt

# Plot histograms for each variable
df.hist(bins=30, figsize=(20,15))
plt.show()

# %%
# Check the distribution of the 'Class' variable
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # Feature Selection
#
# In the previous steps, we used all the features in the dataset for training our models. However, not all features might be relevant for predicting the class variable. Some features might be highly correlated with the class variable, while others might not have any significant correlation. Using irrelevant features can sometimes decrease the performance of the models. Therefore, we will now perform feature selection to identify the most relevant features.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Create a new dataframe with the whole data
df_whole = pd.concat([X, y], axis=1)
# Compute the correlation matrix
corr = df_whole.corr()
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
 
plt.figure(figsize=(20,8))
ax = sns.heatmap(corr.round(2), annot = True, linewidth=0.5, fmt='0.1f', cmap = 'coolwarm')
ax.set_ylim(sorted(ax.get_xlim(), reverse=True))
ax.set(title="Correlation Matrix");
plt.show()

# %% [markdown]
# The heatmap above shows the correlation between different features in the dataset. The 'Class' variable, which we are trying to predict, is most correlated with the features V4, V11, V2, V19, and V20 (positive correlation), and V14, V12, V10, V16, and V17 (negative correlation). We will use these features for training our models.

# %%
# !pip install imbalanced-learn

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 21
#      18     plt.show()
#      20 # Predict the labels for the test set
# ---> 21 y_pred_lof = lof.fit_predict(X_test)
#      22 y_pred_kmeans = kmeans.predict(X_test)
#      23 y_pred_svm = clf.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.model_selection import train_test_split

# Separate input features and target
y = df['Class']
X = df[['V4','V11','V2','V19','V20','V14','V12','V10','V16','V17']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.neighbors import LocalOutlierFactor

# Initialize the model with novelty = False for Classification report 
lof_false = LocalOutlierFactor(n_neighbors=5, algorithm='auto', 
                                              leaf_size=30, metric='minkowski',
                                              p=2, metric_params=None,contamination=0.1)

# Fit the model
lof_false.fit(X_train)
# Out:
# <style>#sk-container-id-11 {color: black;background-color: white;}#sk-container-id-11 pre{padding: 0;}#sk-container-id-11 div.sk-toggleable {background-color: white;}#sk-container-id-11 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-11 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-11 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-11 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-11 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-11 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-11 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200
# ...

# %%
from sklearn.neighbors import LocalOutlierFactor

# Initialize the model novelty = True for confusion matrix
lof = LocalOutlierFactor(n_neighbors=5, algorithm='auto', 
                                              leaf_size=30, metric='minkowski', novelty=True,
                                              p=2, metric_params=None,contamination=0.1)

# Fit the model
lof.fit(X_train)
# Out:
# <style>#sk-container-id-12 {color: black;background-color: white;}#sk-container-id-12 pre{padding: 0;}#sk-container-id-12 div.sk-toggleable {background-color: white;}#sk-container-id-12 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-12 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-12 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-12 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-12 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-12 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-12 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200
# ...

# %%
from sklearn.cluster import KMeans

# Initialize the model
kmeans = KMeans(n_clusters=2, init='k-means++', random_state=42)

# Fit the model
kmeans.fit(X_train)
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
from sklearn import svm

# Initialize the model
clf = svm.SVC(probability=True,kernel='rbf', degree=3, gamma=0.1,max_iter=-1, random_state=42)

# Fit the model
clf.fit(X_train, y_train)
# Out:
# <style>#sk-container-id-6 {color: black;background-color: white;}#sk-container-id-6 pre{padding: 0;}#sk-container-id-6 div.sk-toggleable {background-color: white;}#sk-container-id-6 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-6 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-6 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-6 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-6 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-6 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-6 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-wid
# ...

# %%
# !pip install xgboost

# %%
import xgboost as xgb

# Initialize the model
xg_clf = xgb.XGBClassifier(learning_rate = 0.2, n_estimators= 100, objective='binary:logistic',
                           max_depth= 5, min_child_weight= 3, max_delta_step= 1, subsample= 0.8)

# Fit the model
xg_clf.fit(X_train, y_train)
# Out:
# <style>#sk-container-id-5 {color: black;background-color: white;}#sk-container-id-5 pre{padding: 0;}#sk-container-id-5 div.sk-toggleable {background-color: white;}#sk-container-id-5 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-5 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-5 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-5 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-5 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-5 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-5 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-wid
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Predict the labels for the test set
y_pred_lof = lof_false.fit_predict(X_test)
y_pred_kmeans = kmeans.predict(X_test)
y_pred_svm = clf.predict(X_test)
y_pred_xgb = xg_clf.predict(X_test)

# Map the LOF predictions from -1 and 1 to 0 and 1 to match your target variable.
y_pred_lof = (y_pred_lof == 1).astype(int)

# Print the classification report for each model
print('Classification report for LOF:')
print(classification_report(y_test, y_pred_lof))

print('Classification report for K-means:')
print(classification_report(y_test, y_pred_kmeans))

print('Classification report for SVM:')
print(classification_report(y_test, y_pred_svm))

print('Classification report for XGBoost:')
print(classification_report(y_test, y_pred_xgb))
# Out:
# Classification report for LOF:
#               precision    recall  f1-score   support
#
#            0       1.00      0.10      0.18     85307
#            1       0.00      0.91      0.00       136
#
#     accuracy                           0.10     85443
#    macro avg       0.50      0.51      0.09     85443
# weighted avg       1.00      0.10      0.18     85443
#
# Classification report for K-means:
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81     85307
#            1       0.00      0.05      0.00       136
#
#     accuracy                           0.68     85443
#    macro avg       0.50      0.37      0.41     85443
# weighted avg       1.00      0.68      0.81     85443
#
# Classification report for SVM:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85307
#            1       0.96      0.68      0.80       136
#
# ...

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt

# List of all models and their names for ROC curve
models_roc = [(lof_false, 'LOF'), (kmeans, 'K-means'), (clf, 'SVM'), (xg_clf, 'XGBoost')]
fig, ax = plt.subplots()

# Loop through all models
for model, name in models_roc:
    # Compute predicted probabilities
    if name == 'LOF' or name == 'K-means':
        y_score = model.fit_predict(X_test)
    else:
        y_score = model.predict_proba(X_test)[:,1]
    
    # Compute ROC curve and ROC area
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    
    # Plot ROC curve
    ax.plot(fpr, tpr, label='%s ROC curve (area = %0.2f)' % (name, roc_auc))

# Plot random guess line
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')

# Set plot labels and legends
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# Show plot
plt.show()

# List of all models and their names for confusion matrix
models_cm = [(lof, 'LOF'), (kmeans, 'K-means'), (clf, 'SVM'), (xg_clf, 'XGBoost')]

import seaborn as sns

# Print confusion matrices
for model, name in models_cm:
    # Predict the labels for the test set
    y_pred = model.predict(X_test)
    
    # Map the predicted labels to match with the 'Class' variable encoding only for LOF model
    if name == 'LOF':
        y_pred = np.where(y_pred == -1, 1, 0)

    # Compute confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Create a DataFrame from the confusion matrix
    cm_df = pd.DataFrame(cm, columns=['Predicted Negative', 'Predicted Positive'], 
                         index=['Actual Negative', 'Actual Positive'])
    
    # Create a heatmap from the DataFrame
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    
    # Set the plot title
    plt.title('Confusion Matrix for %s' % name)
    
    # Show the plot
    plt.show()
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LocalOutlierFactor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Random Undersampling
#
# In the previous steps, we used SMOTE for handling the imbalanced dataset. Now, we will try another technique known as Random Undersampling, which works by eliminating instances from the majority class to match the minority class. Let's implement this and see how it affects our models.

# %%
from imblearn.under_sampling import RandomUnderSampler

# define undersample strategy
undersample = RandomUnderSampler(sampling_strategy='majority')

# fit and apply the transform
X_under, y_under = undersample.fit_resample(X, y)

# summarize class distribution
print('After undersampling: class=%d, n=%d' % (0, sum(y_under == 0)))
print('After undersampling: class=%d, n=%d' % (1, sum(y_under == 1)))
# Out:
# After undersampling: class=0, n=492
# After undersampling: class=1, n=492

# %%
from sklearn.model_selection import train_test_split

# Split the undersampled data into training and testing sets
X_train_under, X_test_under, y_train_under, y_test_under = train_test_split(X_under, y_under, test_size=0.25, random_state=42)

# %% [markdown]
# The output shows that we now have an equal number of instances for both classes. We can now proceed to train our models using this undersampled data and compare the results with the models trained using SMOTE.

# %% [markdown]
# # Model Training
#
# We will now train our models using the selected features and the undersampled data. We will start with the Local Outlier Factor model.

# %%
from sklearn.neighbors import LocalOutlierFactor

# Initialize the model with novelty = False for Classification report 
lof_under_false = LocalOutlierFactor(n_neighbors=5, algorithm='auto', 
                                              leaf_size=30, metric='minkowski',
                                              p=2, metric_params=None,contamination=0.1)

# Fit the model
lof_under_false.fit(X_under)
# Out:
# <style>#sk-container-id-19 {color: black;background-color: white;}#sk-container-id-19 pre{padding: 0;}#sk-container-id-19 div.sk-toggleable {background-color: white;}#sk-container-id-19 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-19 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-19 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-19 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-19 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-19 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-19 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200
# ...

# %%
from sklearn.neighbors import LocalOutlierFactor

# Initialize the model with novelty = True for Confusion Matrix
lof_under_true = LocalOutlierFactor(n_neighbors=5, algorithm='auto', 
                                              leaf_size=30, metric='minkowski',
                                              p=2, metric_params=None,contamination=0.1,novelty =True)

# Fit the model
lof_under_true.fit(X_under)
# Out:
# <style>#sk-container-id-20 {color: black;background-color: white;}#sk-container-id-20 pre{padding: 0;}#sk-container-id-20 div.sk-toggleable {background-color: white;}#sk-container-id-20 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-20 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-20 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-20 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-20 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-20 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-20 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200
# ...

# %%
from sklearn.cluster import KMeans

# Initialize the model
kmeans_under = KMeans(n_clusters=2, init='k-means++', random_state=42)

# Fit the model
kmeans.fit(X_under)
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# ...

# %%
from sklearn import svm

# Initialize the model
clf_under = svm.SVC(probability=True,kernel='rbf', degree=3, gamma=0.1,max_iter=-1, random_state=42)

# Fit the model
clf.fit(X_under, y_under)
# Out:
# <style>#sk-container-id-24 {color: black;background-color: white;}#sk-container-id-24 pre{padding: 0;}#sk-container-id-24 div.sk-toggleable {background-color: white;}#sk-container-id-24 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-24 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-24 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-24 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-24 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-24 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-24 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200
# ...

# %%
import xgboost as xgb

# Initialize the model
xg_clf_under = xgb.XGBClassifier(learning_rate = 0.2, n_estimators= 100, objective='binary:logistic',
                           max_depth= 5, min_child_weight= 3, max_delta_step= 1, subsample= 0.8)

# Fit the model
xg_clf.fit(X_under, y_under)
# Out:
# <style>#sk-container-id-23 {color: black;background-color: white;}#sk-container-id-23 pre{padding: 0;}#sk-container-id-23 div.sk-toggleable {background-color: white;}#sk-container-id-23 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.3em;box-sizing: border-box;text-align: center;}#sk-container-id-23 label.sk-toggleable__label-arrow:before {content: "▸";float: left;margin-right: 0.25em;color: #696969;}#sk-container-id-23 label.sk-toggleable__label-arrow:hover:before {color: black;}#sk-container-id-23 div.sk-estimator:hover label.sk-toggleable__label-arrow:before {color: black;}#sk-container-id-23 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-container-id-23 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-container-id-23 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200
# ...

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Predict the labels for the test set
y_under_lof = lof_under_false.fit_predict(X_under)
y_under_kmeans = kmeans.predict(X_under)
y_under_svm = clf.predict(X_under)
y_under_xgb = xg_clf.predict(X_under)

# Map the LOF predictions from -1 and 1 to 0 and 1 to match your target variable.
y_under_lof = (y_under_lof == 1).astype(int)

# Print the classification report for each model
print('Classification report for LOF:')
print(classification_report(y_under, y_under_lof))

print('Classification report for K-means:')
print(classification_report(y_under, y_under_kmeans))

print('Classification report for SVM:')
print(classification_report(y_under, y_under_svm))

print('Classification report for XGBoost:')
print(classification_report(y_under, y_under_xgb))
# Out:
# Classification report for LOF:
#               precision    recall  f1-score   support
#
#            0       0.54      0.11      0.18       492
#            1       0.50      0.91      0.65       492
#
#     accuracy                           0.51       984
#    macro avg       0.52      0.51      0.41       984
# weighted avg       0.52      0.51      0.41       984
#
# Classification report for K-means:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       492
#            1       1.00      0.51      0.67       492
#
#     accuracy                           0.75       984
#    macro avg       0.83      0.75      0.74       984
# weighted avg       0.83      0.75      0.74       984
#
# Classification report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       492
#            1       1.00      0.93      0.96       492
#
# ...

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
import matplotlib.pyplot as plt

# List of all models and their names for ROC curve
models_under_roc = [(lof_under_false, 'LOF'), (kmeans_under, 'K-means'), (clf_under, 'SVM'), (xg_clf_under, 'XGBoost')]
fig, ax = plt.subplots()

# Loop through all models
for model, name in models_under_roc:
    # Fit the model
    model.fit(X_train_under, y_train_under)
    
    # Compute predicted probabilities
    if name == 'LOF' or name == 'K-means':
        y_under_score = model.fit_predict(X_test_under)
    else:
        y_under_score = model.predict_proba(X_test_under)[:,1]
    
    # Compute ROC curve and ROC area
    fpr, tpr, _ = roc_curve(y_test_under, y_under_score)
    roc_auc = auc(fpr, tpr)
    
    # Plot ROC curve
    ax.plot(fpr, tpr, label='%s ROC curve (area = %0.2f)' % (name, roc_auc))

# Plot random guess line
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')

# Set plot labels and legends
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# Show plot
plt.show()


# List of all models and their names for confusion matrix
models_cm = [(lof_under_true, 'LOF'), (kmeans_under, 'K-means'), (clf_under, 'SVM'), (xg_clf_under, 'XGBoost')]

import seaborn as sns

# Print confusion matrices
for model, name in models_cm:
    # Predict the labels for the test set
    y_pred_under = model.predict(X_test_under)
    
    # Map the predicted labels to match with the 'Class' variable encoding only for LOF model
    if name == 'LOF':
        y_pred_under = np.where(y_pred_under == -1, 1, 0)

    # Compute confusion matrix
    cm = confusion_matrix(y_test_under, y_pred_under)
    
    # Create a DataFrame from the confusion matrix
    cm_df = pd.DataFrame(cm, columns=['Predicted Negative', 'Predicted Positive'], 
                         index=['Actual Negative', 'Actual Positive'])
    
    # Create a heatmap from the DataFrame
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    
    # Set the plot title
    plt.title('Confusion Matrix for %s' % name)
    
    # Show the plot
    plt.show()
# Out:
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\user-pc\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# # Model Interpretation

# %% [markdown]
# ## Local Outlier Factor (LOF)
# The LOF model performed poorly on both the undersampled and SMOTE data. The precision for detecting fraudulent transactions was 0.54 for the undersampled data and 0.00 for the SMOTE data. This indicates that the model is not good at correctly identifying positive instances (fraudulent transactions) among all the instances it labeled as positive. The recall was high (0.91 for SMOTE and 0.11 for undersampled), which means the model was able to identify a high proportion of actual positive instances. However, the low precision means that many of the instances it identified as positive were actually negative. The f1-score, which is a measure of the model's accuracy, was also low for both datasets.
#
# The confusion matrix for the LOF model on the SMOTE data shows a high number of false positives (8750), indicating that the model incorrectly labeled many non-fraudulent transactions as fraudulent. On the undersampled data, the model had a high number of false negatives (492), meaning it failed to identify many fraudulent transactions.
#
# ## K-means
# The K-means model performed better on the undersampled data than on the SMOTE data. The precision, recall, and f1-score were all higher for the undersampled data. However, the model still had a relatively high number of false positives (27139) on the SMOTE data, indicating that it incorrectly labeled many non-fraudulent transactions as fraudulent.
#
# ## Support Vector Machine (SVM)
# The SVM model performed well on both the undersampled and SMOTE data. It had high precision, recall, and f1-scores for both datasets, indicating that it was good at correctly identifying fraudulent transactions and had a low rate of false positives and false negatives. The confusion matrices for the SVM model show a low number of false positives and false negatives, further indicating the model's good performance.
#
# ## XGBoost
# The XGBoost model performed exceptionally well on both the undersampled and SMOTE data. It had perfect precision, recall, and f1-scores for the undersampled data, and near-perfect scores for the SMOTE data. This indicates that the model was excellent at correctly identifying fraudulent transactions and had a very low rate of false positives and false negatives. The confusion matrices for the XGBoost model show a very low number of false positives and false negatives, further indicating the model's excellent performance.
#
# In conclusion, the SVM and XGBoost models performed the best on both the undersampled and SMOTE data. The LOF model performed the worst, and the K-means model performed moderately well on the undersampled data but poorly on the SMOTE data. These results suggest that SVM and XGBoost are the most suitable models for this task, while LOF is the least suitable.
